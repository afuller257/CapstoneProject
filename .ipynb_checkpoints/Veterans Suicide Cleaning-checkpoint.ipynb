# %%
#import libraries
import pandas as pd

#read csv.file
df = pd.read_csv('2005.csv')

# Replace all NaN values with 0
df.fillna(0, inplace=True)

#drop unwanted columns
df = df.drop(columns=['vet_males','vet_males_p','vet_females','vet_females_p','vet_15_24','vet_18_29','vet_17_34','vet_25_34','vet_30_39','vet_25_44','vet_35_44','vet_40_49','vet_35-54','vet_45_54','vet_50_59','vet_45_64','vet_55_64','vet_60','vet_65'])

# Rename all columns, except 'column_to_skip'
columns_to_rename = {col: f"2005_{col}" for col in df.columns if col not in ['state number', 'state']}
df = df.rename(columns=columns_to_rename)

# Write the cleaned DataFrame to a new CSV file
df.to_csv('cleaned_2005.csv', index=False)

#read csv.file
df = pd.read_csv('2006.csv')

# Replace all NaN values with 0
df.fillna(0, inplace=True)

#drop unwanted columns
df = df.drop(columns=['vet_males','vet_males_p','vet_females','vet_females_p','vet_15_24','vet_18_29','vet_17_34','vet_25_34','vet_30_39','vet_25_44','vet_35_44','vet_40_49','vet_35-54','vet_45_54','vet_50_59','vet_45_64','vet_55_64','vet_60','vet_65'])

# Rename all columns, except 'column_to_skip'
columns_to_rename = {col: f"2006_{col}" for col in df.columns if col not in ['state number', 'state']}
df = df.rename(columns=columns_to_rename)

# Write the cleaned DataFrame to a new CSV file
df.to_csv('cleaned_2006.csv', index=False)

#read csv.file
df = pd.read_csv('2007.csv')

# Replace all NaN values with 0
df.fillna(0, inplace=True)

#drop unwanted columns
df = df.drop(columns=['vet_males','vet_males_p','vet_females','vet_females_p','vet_15_24','vet_18_29','vet_17_34','vet_25_34','vet_30_39','vet_25_44','vet_35_44','vet_40_49','vet_35-54','vet_45_54','vet_50_59','vet_45_64','vet_55_64','vet_60','vet_65'])

# Rename all columns, except 'column_to_skip'
columns_to_rename = {col: f"2007_{col}" for col in df.columns if col not in ['state number', 'state']}
df = df.rename(columns=columns_to_rename)

# Write the cleaned DataFrame to a new CSV file
df.to_csv('cleaned_2007.csv', index=False)

#read csv.file
df = pd.read_csv('2008.csv')

# Replace all NaN values with 0
df.fillna(0, inplace=True)

#drop unwanted columns
df = df.drop(columns=['vet_males','vet_males_p','vet_females','vet_females_p','vet_15_24','vet_18_29','vet_17_34','vet_25_34','vet_30_39','vet_25_44','vet_35_44','vet_40_49','vet_35-54','vet_45_54','vet_50_59','vet_45_64','vet_55_64','vet_60','vet_65'])

# Rename all columns, except 'column_to_skip'
columns_to_rename = {col: f"2008_{col}" for col in df.columns if col not in ['state number', 'state']}
df = df.rename(columns=columns_to_rename)

# Write the cleaned DataFrame to a new CSV file
df.to_csv('cleaned_2008.csv', index=False)

#read csv.file
df = pd.read_csv('2009.csv')

# Replace all NaN values with 0
df.fillna(0, inplace=True)

#drop unwanted columns
df = df.drop(columns=['vet_males','vet_males_p','vet_females','vet_females_p','vet_15_24','vet_18_29','vet_17_34','vet_25_34','vet_30_39','vet_25_44','vet_35_44','vet_40_49','vet_35-54','vet_45_54','vet_50_59','vet_45_64','vet_55_64','vet_60','vet_65'])

# Rename all columns, except 'column_to_skip'
columns_to_rename = {col: f"2009_{col}" for col in df.columns if col not in ['state number', 'state']}
df = df.rename(columns=columns_to_rename)

# Write the cleaned DataFrame to a new CSV file
df.to_csv('cleaned_2009.csv', index=False)

#read csv.file
df = pd.read_csv('2010.csv')

# Replace all NaN values with 0
df.fillna(0, inplace=True)

#drop unwanted columns
df = df.drop(columns=['vet_males','vet_males_p','vet_females','vet_females_p','vet_15_24','vet_18_29','vet_17_34','vet_25_34','vet_30_39','vet_25_44','vet_35_44','vet_40_49','vet_35-54','vet_45_54','vet_50_59','vet_45_64','vet_55_64','vet_60','vet_65'])

# Rename all columns, except 'column_to_skip'
columns_to_rename = {col: f"2010_{col}" for col in df.columns if col not in ['state number', 'state']}
df = df.rename(columns=columns_to_rename)

# Write the cleaned DataFrame to a new CSV file
df.to_csv('cleaned_2010.csv', index=False)

#read csv.file
df = pd.read_csv('2011.csv')

# Replace all NaN values with 0
df.fillna(0, inplace=True)

#drop unwanted columns
df = df.drop(columns=['vet_males','vet_males_p','vet_females','vet_females_p','vet_15_24','vet_18_29','vet_17_34','vet_25_34','vet_30_39','vet_25_44','vet_35_44','vet_40_49','vet_35-54','vet_45_54','vet_50_59','vet_45_64','vet_55_64','vet_60','vet_65'])

# Rename all columns, except 'column_to_skip'
columns_to_rename = {col: f"2011_{col}" for col in df.columns if col not in ['state number', 'state']}
df = df.rename(columns=columns_to_rename)

# Write the cleaned DataFrame to a new CSV file
df.to_csv('cleaned_2011.csv', index=False)


df1 = pd.read_csv('cleaned_2005.csv')
df2 = pd.read_csv('cleaned_2006.csv')
df3 = pd.read_csv('cleaned_2007.csv')
df4 = pd.read_csv('cleaned_2008.csv')
df5 = pd.read_csv('cleaned_2009.csv')
df6 = pd.read_csv('cleaned_2010.csv')
df7 = pd.read_csv('cleaned_2011.csv')

merged_df = pd.concat([df1, df2, df3, df4, df5, df6, df7], axis=1)

#remove duplicate columns for new dataframe
merged_df = merged_df.loc[:,~merged_df.columns.duplicated()]


# Write the cleaned DataFrame to a new CSV file
merged_df.to_csv('combined_cleaned.csv', index=False)
