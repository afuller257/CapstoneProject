# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('combined_cleaned.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 64 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   state number         50 non-null     int64
#  1   2005_state           50 non-null     object
#  2   2005_vet_pop         50 non-null     int64
#  3   2005_overall_pop_18  50 non-null     int64
#  4   2005_vet_pop_p       50 non-null     float64
#  5   2005_vet_suicides    50 non-null     int64
#  6   2005_all_suicides    50 non-null     int64
#  7   2005_vet_suicides_p  50 non-null     float64
#  8   2005_vet_rate        50 non-null     float64
#  9   2005_civ_rate        50 non-null     float64
#  10  2006_state           50 non-null     object
#  11  2006_vet_pop         50 non-null     int64
#  12  2006_overall_pop_18  50 non-null     int64
#  13  2006_vet_pop_p       50 non-null     float64
#  14  2006_vet_suicides    50 non-null     int64
# ...

# %%
df.head()
df.describe()
# Out:
#        state number  2005_vet_pop  2005_overall_pop_18  2005_vet_pop_p  \
# count      50.00000  5.000000e+01         5.000000e+01       50.000000
# mean       24.50000  4.679125e+05         4.282440e+06        0.119000
# std        14.57738  4.487113e+05         4.698609e+06        0.017069
# min         0.00000  5.551900e+04         3.796510e+05        0.077787
# 25%        12.25000  1.476658e+05         1.300598e+06        0.109795
# 50%        24.50000  3.460585e+05         3.075282e+06        0.120555
# 75%        36.75000  5.445478e+05         4.702879e+06        0.128980
# max        49.00000  2.193336e+06         2.554345e+07        0.166638
#
#        2005_vet_suicides  2005_all_suicides  2005_vet_suicides_p  \
# count          50.000000          50.000000            50.000000
# mean          136.920000         652.080000             0.207965
# std           134.362568         626.997407             0.047993
# min            10.000000          71.000000             0.077739
# ...

# %%
df['Price'].hist()
plt.show()

# %%
df.plot.scatter(x='Price', y='Company')
plt.show()
